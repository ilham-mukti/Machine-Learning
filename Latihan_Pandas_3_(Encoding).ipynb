# %% [markdown]
# <a href="https://colab.research.google.com/github/ilham-mukti/Machine-Learning/blob/main/Latihan_Pandas_3_(Encoding).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
datas = pd.read_csv('/content/data_jakarta.csv')
datas.head()
# Out:
#    tahun nama_provinsi  ...       jenis_pekerajaan jumlah
# 0   2018   DKI Jakarta  ...    Belum/Tidak Bekerja   1474
# 1   2018   DKI Jakarta  ...  Mengurus Rumah Tangga   1625
# 2   2018   DKI Jakarta  ...      Pelajar/Mahasiswa   1800
# 3   2018   DKI Jakarta  ...              Pensiunan     19
# 4   2018   DKI Jakarta  ...   Pegawai Negeri Sipil    223
#
# [5 rows x 7 columns]

# %%
datas.shape
# Out:
# (11508, 7)

# %%
datas.isna().sum()
# Out:
# tahun               0
# nama_provinsi       0
# nama_kabupaten      0
# nama_kecamatan      0
# nama_kelurahan      0
# jenis_pekerajaan    0
# jumlah              0
# dtype: int64

# %%
datas.nunique()
# Out:
# tahun                  1
# nama_provinsi          1
# nama_kabupaten         6
# nama_kecamatan        44
# nama_kelurahan       267
# jenis_pekerajaan      87
# jumlah              2036
# dtype: int64

# %%
datas.nama_kabupaten.value_counts()
# Out:
# JAKARTA TIMUR            2886
# JAKARTA SELATAN          2846
# JAKARTA BARAT            2423
# JAKARTA PUSAT            1833
# JAKARTA UTARA            1375
# ADM. KEPULAUAN SERIBU     145
# Name: nama_kabupaten, dtype: int64

# %%
datas.groupby(['nama_kabupaten', 'nama_kecamatan']).mean()
# Out:
#                                                  tahun       jumlah
# nama_kabupaten        nama_kecamatan
# ADM. KEPULAUAN SERIBU KEPULAUAN SERIBU SELATAN  2018.0   162.347222
#                       KEPULAUAN SERIBU UTARA    2018.0   227.397260
# JAKARTA BARAT         CENGKARENG                2018.0  2016.564103
#                       GROGOL PETAMBURAN         2018.0   758.214058
#                       KALI DERES                2018.0  1802.751055
#                       KEBON JERUK               2018.0  1036.325444
#                       KEMBANGAN                 2018.0  1038.460714
#                       PAL MERAH                 2018.0   843.365314
#                       TAMAN SARI                2018.0   441.900685
#                       TAMBORA                   2018.0   647.959427
# JAKARTA PUSAT         CEMPAKA PUTIH             2018.0   692.130137
#                       GAMBIR                    2018.0   450.517857
# ...

# %%
datas.pivot_table(index='nama_kabupaten', columns='nama_kecamatan', values='jumlah', aggfunc='mean')
# Out:
# nama_kecamatan              CAKUNG  CEMPAKA PUTIH  ...  TANJUNG PRIOK       TEBET
# nama_kabupaten                                     ...
# ADM. KEPULAUAN SERIBU          NaN            NaN  ...            NaN         NaN
# JAKARTA BARAT                  NaN            NaN  ...            NaN         NaN
# JAKARTA PUSAT                  NaN     692.130137  ...            NaN         NaN
# JAKARTA SELATAN                NaN            NaN  ...            NaN  761.415335
# JAKARTA TIMUR          1741.474522            NaN  ...            NaN         NaN
# JAKARTA UTARA                  NaN            NaN  ...    1299.273016         NaN
#
# [6 rows x 44 columns]

# %%
datas.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
datas.groupby(['nama_kabupaten', 'nama_kecamatan']).size()
# Out:
# nama_kabupaten         nama_kecamatan
# ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN     72
#                        KEPULAUAN SERIBU UTARA       73
# JAKARTA BARAT          CENGKARENG                  273
#                        GROGOL PETAMBURAN           313
#                        KALI DERES                  237
#                        KEBON JERUK                 338
#                        KEMBANGAN                   280
#                        PAL MERAH                   271
#                        TAMAN SARI                  292
#                        TAMBORA                     419
# JAKARTA PUSAT          CEMPAKA PUTIH               146
#                        GAMBIR                      224
#                        JOHAR BARU                  182
#                        KEMAYORAN                   341
#                        MENTENG                     216
#                        S E N E N                   244
# ...

# %%
nama
